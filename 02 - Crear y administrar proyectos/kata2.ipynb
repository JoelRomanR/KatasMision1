# %% [markdown]
# # Entornos virtuales

# %% [markdown]
# ### Se crea el entorno virtual con el comando python -m venv env en la consola
#
# <img src="imgs/01 - creacion del entorno.png">

# %% [markdown]
# #### Muestra de que la creación fue exitosa al aparecer unas carpetas y archivos en la ruta seleccionada
#
# <img src="imgs/02 - visualizacion del entorno.png">

# %% [markdown]
# ### Activación del entorno con el comando ene\Scripts\activate.bat
#
# <img src="imgs/03 - activar el entorno.png">

# %% [markdown]
# ### Posteriormente se instalan librerías adicionales con el comando pip install python-dateutil
#
# <img src="imgs/04 - instalacion de librerias.png">

# %% [markdown]
# ### Por ultimo se comprueba que las librerías previamente instaladas están presentes en el entorno virtual creado, se usó el comando pip freeze
#
# <img src="imgs/05 - visualizacion de las librerias en el entorno.png">
