# %% [markdown]
# # Manejo de errores

# %% [markdown]
# ### Muestra de un error al no encontrar un archivo
#
# <img src="imgs/01 - muestra de error al no encontrar un archivo.png">

# %% [markdown]
# ### Uso de Try y Except para agregar información en el error para una mejor lectura
#
# <img src="imgs/02 - try y except.png">

# %% [markdown]
# ### Generacion de excepciones para obtener información de un proceso en el código
#
# <img src="imgs/03 - generacion de excepciones.png">

# %% [markdown]
# ### Uso de "TypeError" para complementar la información en un error de tipos no admitidos
#
# <img src="imgs/04 - uso de TypeError.png">
